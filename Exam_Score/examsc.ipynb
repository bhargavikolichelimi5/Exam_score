# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
df=pd.read_csv(r"C:\Users\Dell\Searches\Downloads\archive (5)\Exam_Score_Prediction.csv")
#pd.set_option("display.max_rows", None)
df
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
print(df.ndim)
print(df.size)
print(df.dtypes)
# Out:
# 2
# 260000
# student_id            int64
# age                   int64
# gender               object
# course               object
# study_hours         float64
# class_attendance    float64
# internet_access      object
# sleep_hours         float64
# sleep_quality        object
# study_method         object
# facility_rating      object
# exam_difficulty      object
# exam_score          float64
# dtype: object

# %%
df.shape
# Out:
# (20000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  object
#  3   course            20000 non-null  object
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  object
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  object
#  9   study_method      20000 non-null  object
#  10  facility_rating   20000 non-null  object
#  11  exam_difficulty   20000 non-null  object
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.0+ MB

# %%
df.columns
df.keys()
# Out:
# Index(['student_id', 'age', 'gender', 'course', 'study_hours',
#        'class_attendance', 'internet_access', 'sleep_hours', 'sleep_quality',
#        'study_method', 'facility_rating', 'exam_difficulty', 'exam_score'],
#       dtype='object')

# %%
df["course"]
print(df["course"].describe())
# Out:
# count     20000
# unique        7
# top         bca
# freq       2902
# Name: course, dtype: object

# %%
df["class_attendance"]
print(df["class_attendance"].describe())
# Out:
# count    20000.000000
# mean        70.017365
# std         17.282262
# min         40.600000
# 25%         55.100000
# 50%         69.900000
# 75%         85.000000
# max         99.400000
# Name: class_attendance, dtype: float64

# %%
df["facility_rating"]
print(df["facility_rating"].describe())
# Out:
# count      20000
# unique         3
# top       medium
# freq        6760
# Name: facility_rating, dtype: object

# %%
df["exam_difficulty"]
print(df["exam_difficulty"].describe())
# Out:
# count        20000
# unique           3
# top       moderate
# freq          9878
# Name: exam_difficulty, dtype: object

# %%
df["exam_score"]
print(df["exam_score"].describe())
# Out:
# count    20000.000000
# mean        62.513225
# std         18.908491
# min         19.599000
# 25%         48.800000
# 50%         62.600000
# 75%         76.300000
# max        100.000000
# Name: exam_score, dtype: float64

# %%
df["internet_access"]
print(df["internet_access"].describe())
# Out:
# count     20000
# unique        2
# top         yes
# freq      16988
# Name: internet_access, dtype: object

# %%
df["study_method"]
print(df["study_method"].describe())
# Out:
# count          20000
# unique             5
# top       self-study
# freq            4079
# Name: study_method, dtype: object

# %%
df["gender"]
print(df["gender"].describe())
# Out:
# count     20000
# unique        3
# top       other
# freq       6726
# Name: gender, dtype: object

# %%
print(df["sleep_hours"].unique())
print(df["sleep_hours"].value_counts())
# Out:
# [7.4 4.6 8.5 5.8 9.8 4.2 8.2 6.6 4.1 8.1 7.1 7.7 7.3 8.3 6.8 4.4 4.3 9.7
#  6.3 8.  6.7 7.  5.1 6.5 5.4 9.5 5.5 7.6 7.8 8.9 5.2 6.9 4.9 5.6 5.9 9.3
#  9.6 9.2 8.8 8.4 5.3 9.9 8.7 7.2 4.5 9.1 4.7 9.  6.1 7.9 6.2 5.  9.4 4.8
#  7.5 5.7 8.6 6.4 6. ]
# sleep_hours
# 4.1    515
# 9.9    497
# 9.2    370
# 6.2    367
# 5.9    362
# 7.3    362
# 8.6    360
# 5.5    360
# 9.7    359
# 6.4    359
# 5.3    357
# 6.1    354
# 7.4    351
# 5.2    349
# 7.1    346
# 6.7    345
# 4.2    344
# 8.7    343
# 8.9    341
# 4.5    340
# 7.7    340
# 9.6    340
# 9.0    339
# 9.8    337
# 8.8    336
# 7.9    336
# 9.5    336
# 4.9    335
# 7.5    335
# 5.0    334
# 4.6    334
# 5.8    332
# 9.1    331
# 7.8    329
# 9.3    329
# 9.4    329
# 7.6    328
# 4.8    327
# 7.2    327
# 8.3    326
# 5.6    324
# 6.6    321
# 6.9    321
# 6.0    320
# 5.7    320
# 8.1    318
# 6.3    317
# 4.7    317
# 7.0    316
# 8.5    315
# 5.1    315
# 4.4    313
# 8.2    312
# 6.5    311
# 8.4    308
# 6.8    306
# ...

# %%
print(df["exam_score"].unique())
print(df["exam_score"].value_counts())
# Out:
# [ 58.9    54.8    90.3    29.7    43.7    58.2    53.7    47.3    44.9
#   77.7    63.2    53.5    63.9    34.1    83.5    98.5    70.3    32.3
#   56.2    49.3    68.1    52.1    47.1    84.8    68.9    76.3    71.6
#   74.1    56.6    49.2    97.5    81.8    65.6    71.1    60.3    81.3
#   37.3    52.     65.8    67.6    99.3    33.6    35.5    42.8   100.
#   50.4    74.     30.9    75.9    75.3    88.7    73.6    76.8    64.9
#   47.2    78.1    77.8    66.9    70.5    57.2    75.5    62.8    31.7
#   19.599  54.     61.     35.1    57.5    26.4    45.3    46.9    37.1
#   78.8    49.9    76.9    54.4    28.3    53.1    75.6    59.8    51.3
#   23.9    48.1    65.3    79.5    79.9    61.1    49.     66.3    49.5
#   40.     78.7    61.4    69.6    71.9    88.5    63.8    51.1    91.3
#   95.2    74.3    64.     79.6    51.8    74.4    69.9    26.5    45.5
#   57.     52.8    93.1    81.6    51.9    51.     86.9    67.4    40.7
# ...

# %%
print(df["study_hours"].unique())
print(df["study_hours"].value_counts())
# Out:
# [2.78 3.37 7.88 0.67 0.89 3.48 1.35 5.48 2.89 6.77 5.99 3.77 6.76 0.81
#  4.65 4.84 1.97 0.4  4.28 4.11 5.23 1.7  1.44 7.82 0.91 7.91 5.76 5.03
#  2.72 6.94 7.28 5.78 5.68 3.95 0.62 0.12 3.96 2.94 6.21 5.89 5.02 0.6
#  1.89 0.75 7.83 1.02 7.74 0.9  6.9  4.6  6.65 5.07 6.15 5.85 2.08 7.48
#  5.15 1.62 2.45 4.26 7.05 6.37 2.42 5.51 0.08 2.66 6.72 1.21 2.83 0.19
#  1.17 3.92 7.2  0.68 6.96 5.35 2.32 1.55 6.31 5.8  2.44 0.43 5.04 0.72
#  4.29 4.9  5.5  1.   3.68 3.71 6.68 3.75 3.25 0.99 5.56 4.96 5.74 5.25
#  7.   7.02 2.46 1.46 7.41 5.7  7.77 3.98 7.7  0.98 4.72 3.97 1.54 1.23
#  0.49 7.59 7.72 7.13 7.46 1.58 2.06 3.84 4.5  2.28 2.88 4.94 3.36 3.8
#  5.42 3.66 7.6  3.88 7.69 6.78 6.11 4.41 1.61 1.72 0.27 5.96 4.66 1.1
#  0.53 4.27 6.98 2.85 7.35 3.73 2.53 0.28 5.24 1.67 7.21 2.69 3.26 2.34
#  6.64 1.08 2.37 3.23 4.74 7.71 2.1  2.63 2.98 5.4  5.92 0.94 7.12 6.71
#  1.51 7.47 5.71 6.26 3.67 6.39 3.82 2.84 5.88 4.58 3.47 5.61 5.87 4.62
# ...

# %%
print(df["course"].unique())
print(df["course"].value_counts())
# Out:
# ['diploma' 'bca' 'b.sc' 'b.tech' 'bba' 'ba' 'b.com']
# course
# bca        2902
# ba         2896
# b.sc       2878
# b.com      2864
# bba        2836
# diploma    2826
# b.tech     2798
# Name: count, dtype: int64

# %%
print(df["study_method"].unique())
print(df["study_method"].value_counts())
# Out:
# ['coaching' 'online videos' 'mixed' 'self-study' 'group study']
# study_method
# self-study       4079
# online videos    4069
# coaching         4036
# group study      3922
# mixed            3894
# Name: count, dtype: int64

# %%
print(df["facility_rating"].unique())
print(df["facility_rating"].value_counts())
# Out:
# ['low' 'medium' 'high']
# facility_rating
# medium    6760
# low       6638
# high      6602
# Name: count, dtype: int64

# %%
import math
df['study_hours'].mean()
df['study_hours'].median()
df['study_hours'].mode()
df['study_hours'].var()
df['study_hours'].std()
# Out:
# 2.308312902795194

# %%
import math
df['exam_score'].mean()
df['exam_score'].median()
df['exam_score'].mode()
df['exam_score'].var()
df['exam_score'].std()
# Out:
# 18.908491165645056

# %%
df['class_attendance'].mean()
df['class_attendance'].median()
df['class_attendance'].mode()
df['class_attendance'].var()
df['class_attendance'].std()
# Out:
# 17.2822621431922

# %%
plt.boxplot(df["class_attendance"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a6a3476210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a6a3488b90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a6a34747d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a6a3488e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a6a3488f50>],
#  'means': []}

# %%
plt.boxplot(df["exam_score"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a6a3622350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a6a36225d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a6a3622210>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a6a3622850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a6a3622990>],
#  'means': []}

# %%
plt.boxplot(df["study_hours"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a6a368f4d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a6a335b750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a6a368f390>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a6a368f750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a6a368f890>],
#  'means': []}

# %%
sns.histplot(x=df["exam_score"],bins=5)
# Out:
# <Axes: xlabel='class_attendance', ylabel='Count'>

# %%
sns.histplot(x=df["exam_score"],bins=5)
# Out:
# <Axes: xlabel='exam_score', ylabel='Count'>

# %%
sns.histplot(x=df["study_hours"],bins=5)
# Out:
# <Axes: xlabel='study_hours', ylabel='Count'>

# %%
sns.histplot(x=df["student_id"],bins=5)
# Out:
# <Axes: xlabel='student_id', ylabel='Count'>

# %%
sns.histplot(x=df["exam_difficulty"],bins=5)
# Out:
# <Axes: xlabel='exam_difficulty', ylabel='Count'>

# %%
sns.histplot(x=df["course"],bins=5)
# Out:
# <Axes: xlabel='course', ylabel='Count'>

# %%
sns.kdeplot(x=df["study_hours"])
# Out:
# <Axes: xlabel='study_hours', ylabel='Density'>

# %%
sns.kdeplot(x=df["exam_score"])
# Out:
# <Axes: xlabel='exam_score', ylabel='Density'>

# %%
sns.kdeplot(x=df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(x=df["age"],bins=5,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(x=df["exam_score"],bins=5,kde=True)
# Out:
# <Axes: xlabel='exam_score', ylabel='Count'>

# %%
sns.histplot(x=df["study_hours"],bins=5,kde=True)
# Out:
# <Axes: xlabel='study_hours', ylabel='Count'>

# %%
plt.pie(x=df["course"].value_counts(),labels=df["course"].value_counts().index,autopct="%0.1f%%")
plt.show()

# %%
plt.pie(x=df["exam_difficulty"].value_counts(),labels=df["exam_difficulty"].value_counts().index,autopct="%0.1f%%")
plt.show()
